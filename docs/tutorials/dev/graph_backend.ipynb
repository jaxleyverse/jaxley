# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # The graph backend for SWC files

# %% [markdown]
# `Jaxley` has a graph backend for SWC files. This backend is based on `networkX`. This tutorial is aimed at developers that want to better understand the graph backend. For this, we will provide a full run-through of every step from an SWC file to a `jx.Cell`.

# %% [markdown]
# ## I) Import the SWC file into `networkX`

# %%
from jaxley.io.graph import to_swc_graph

# swc_graph = to_swc_graph("../data/example.swc")
swc_graph = to_swc_graph("../../../tests/swc_files/morph_ca1_n120_single_point_soma.swc")

# %%
swc_graph.nodes[1]
# Out:
# {'id': 1,
#  'x': np.float64(1.269999862),
#  'y': np.float64(-4.367499828),
#  'z': np.float64(0.0),
#  'r': np.float64(10.327666283),
#  'p': -1}

# %% [markdown]
# The `swc_graph` is a `nx.DiGraph`. The directionality indicates the direction in which the SWC file was traced. We can inspect this graph as follows:

# %%
import numpy as np
np.max(swc_graph.nodes)
# Out:
# np.int64(2619)

# %%
import networkx as nx
import matplotlib.pyplot as plt

pos = {k: (v["x"], v["y"]) for k, v in swc_graph.nodes.items()}
fig, ax = plt.subplots(1, 1, figsize=(2, 4))
nx.draw(swc_graph, pos=pos, with_labels=True, font_size=7, node_size=150, ax=ax)

# %%
print("nodes", swc_graph.nodes[1])
print("edges", swc_graph.edges[(1, 2)])
# Out:
# nodes {'id': 1, 'x': np.float64(1.269999862), 'y': np.float64(-4.367499828), 'z': np.float64(0.0), 'r': np.float64(10.327666283), 'p': -1}
# edges {'l': np.float64(17.560683789812973)}

# %% [markdown]
# ## II) Build the compartment graph

# %% [markdown]
# Next, `Jaxley` traverses this morphology and clusters connected (i.e., uninterrupted) segments into branches. It also adds branchpoints between compartments where the branch index changes.

# %%
from jaxley.io.graph import build_compartment_graph

comp_graph, single_point_soma = build_compartment_graph(swc_graph, ncomp=1)

# %% [markdown]
# We can visualize such compartment graphs with `vis_compartment_graph()`:

# %%
from jaxley.io.graph import vis_compartment_graph

fig, ax = plt.subplots(1, 1, figsize=(8, 3))
vis_compartment_graph(comp_graph, ax=ax)

# %% [markdown]
# The red nodes are compartments, the orange nodes are branchpoints. Below, we show their attributes:

# %%
print(f"Compartment nodes: {comp_graph.nodes[2]}")
print(f"Branchpoint nodes: {comp_graph.nodes[8]}")
# print(f"Edges: {comp_graph.edges[(8, 2)]}")
# Out:
# Compartment nodes: {'x': 10.814626693725586, 'y': -152.1248321533203, 'z': 5.060335159301758, 'branch_index': 2, 'comp_index': 2, 'type': 'comp', 'xyzr': array([[  12.31000042, -122.33000183,    5.84000015,    1.34000003,
#           27.        ],
#        [  10.98999977, -131.17999268,   -5.59000015,    1.02999997,
#           28.        ],
#        [  11.05000019, -136.22000122,   -1.36000001,    1.02999997,
#           29.        ],
#        [  11.27999973, -141.24000549,   12.22999954,    1.02999997,
#           30.        ],
#        [  10.85000038, -146.52999878,   12.22999954,    1.02999997,
#           31.        ],
#        [  10.63000011, -148.53999329,   12.22999954,    1.02999997,
#           32.        ],
#        [  10.98999977, -155.52999878,   -1.75      ,    1.02999997,
#           33.        ],
#        [   9.35999966, -168.22000122,    6.        ,    1.02999997,
#           34.        ],
#        [   9.81000042, -172.30000305,    4.1500001 ,    1.02999997,
#           35.        ],
#        [   8.06999969, -178.32000732,    2.16000009,    1.17999995,
#           36.        ],
#        [   8.10000038, -178.5       ,   19.44000053,    1.17999995,
#           37.        ]]), 'area': 692.8006044340332, 'volume': 376.87462960070206, 'resistive_load_in': 14.274194170054246, 'resistive_load_out': 13.796577063667195, 'groups': ['apical'], 'radius': 1.0823749454764062, 'length': 101.86565074129777, 'cell_index': 0}
# Branchpoint nodes: {'x': 0.4350000023841858, 'y': -252.16000366210938, 'z': 11.770000457763672, 'branch_index': 8, 'comp_index': 8, 'type': 'comp', 'xyzr': array([[ 6.99999988e-01, -2.51039993e+02,  1.35200005e+01,
#          8.70000005e-01,  5.10000000e+01],
#        [ 1.70000002e-01, -2.53279999e+02,  1.00200005e+01,
#          8.70000005e-01,  5.20000000e+01]]), 'area': 22.899153473359966, 'volume': 9.961131818159469, 'resistive_load_in': 0.8808499332294096, 'resistive_load_out': 0.8808499332294096, 'groups': ['apical'], 'radius': 0.870000005, 'length': 4.189095916045637, 'cell_index': 0}

# %% [markdown]
# ## III) Build the solve graph

# %% [markdown]
# The above compartment graph can be modified in any way (as long as it stays acyclic). After all modifications, `Jaxley` traverses the compartment graph again to identify the `branch_index` and the order of the `solve` (the solve is ordered because of the implicit Euler solver). You can modify the order of the traversal with the `solve_root` argument.

# %%
from jaxley.io.graph import from_graph

cell = from_graph(comp_graph, solve_root=0, num_swc_nodes=len(swc_graph.nodes), single_point_soma=single_point_soma)

# %%
cell.swc_to_comp[1]
# Out:
# np.int64(0)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 4))
_ = cell.vis(ax=ax)
_ = cell.branch(cell.swc_to_comp[1228]).vis(ax=ax, color="r")

# %% [markdown]
# Internally, the following happens during `from_graph`:
# - `_remove_branch_points_at_tips()`: Removes the branch points which have only one neighbor (which can exist because you, e.g.  edited the morphology)
# - `_set_comp_and_branch_index()`: traverses the `comp_graph` and sets the `comp_index` and `branch_index`. This step is necessary if the morphology was edited.
# - `_remove_branch_points()` removes all branchpoints. Instead, the directionality of the edges indicates the solve order (and in a way that every compartment has only one parent compartment after this stage)
# - `_add_meta_data()` adds the `type="cell"` and assembles the `xyzr` from all compartments into a global `graph.graph["xyzr"]`
# - `_build_module()` builds a `pd.DataFrame` from the graph and uses it to create a `jx.Cell` with appropriate `cell.nodes`
#
# As such, you can get more control by replacing `from_graph` with:

# %%
from jaxley.io.graph import (
    _remove_branch_points_at_tips,
    _set_comp_and_branch_index,
    _remove_branch_points,
    _add_meta_data,
    _build_module,
)

comp_graph = _remove_branch_points_at_tips(comp_graph)
comp_graph = _set_comp_and_branch_index(comp_graph, root=0)
solve_graph = _remove_branch_points(comp_graph)
solve_graph = _add_meta_data(solve_graph)
cell = _build_module(solve_graph)

# %% [markdown]
# For more information on how to work with morphologies, see also [this tutorial](https://jaxley.readthedocs.io/en/latest/tutorials/08_importing_morphologies.html).
